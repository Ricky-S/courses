# %% [markdown]
# <a href="http://cocl.us/pytorch_link_top">
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0110EN/notebook_images%20/Pytochtop.png" width="750" alt="IBM Product " />
# </a>

# %% [markdown]
# <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0110EN/notebook_images%20/cc-logo-square.png" width="200" alt="cognitiveclass.ai logo" />

# %% [markdown]
# <h1>Simple One Hidden Layer Neural Network</h1>

# %% [markdown]
# <h2>Table of Contents</h2>
# <p>In this lab, you will use a single-layer neural network to classify non linearly seprable data in 1-Ddatabase.</p>
#
# <ul>
#     <li><a href="#Model">Neural Network Module and Training Function</a></li>
#     <li><a href="#Makeup_Data">Make Some Data</a></li>
#     <li><a href="#Train">Define the Neural Network, Criterion Function, Optimizer, and Train the Model</a></li>
# </ul>
# <p>Estimated Time Needed: <strong>25 min</strong></p>
#
# <hr>

# %% [markdown]
# <h2>Preparation</h2>

# %% [markdown]
# We'll need the following libraries

# %%
# Import the libraries we need for this lab

import torch 
import torch.nn as nn
from torch import sigmoid
import matplotlib.pylab as plt
import numpy as np
torch.manual_seed(0)

# %% [markdown]
# Used for plotting the model

# %%
# The function for plotting the model

def PlotStuff(X, Y, model, epoch, leg=True):
    
    plt.plot(X.numpy(), model(X).detach().numpy(), label=('epoch ' + str(epoch)))
    plt.plot(X.numpy(), Y.numpy(), 'r')
    plt.xlabel('x')
    if leg == True:
        plt.legend()
    else:
        pass

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# <h2 id="Model">Neural Network Module and Training Function</h2>

# %% [markdown]
# Define the activations and the output of the first linear layer as an attribute. Note that this is not good practice.

# %%
# Define the class Net

class Net(nn.Module):
    
    # Constructor
    def __init__(self, D_in, H, D_out):
        super(Net, self).__init__()
        # hidden layer 
#         we use the linear class to represent each layer. 
#         The hidden layer is given by the first linear constructor
#         we start with the size of the input to the network
#         H is the number of neurons, it is the size of the output of the linear function
        self.linear1 = nn.Linear(D_in, H)
#         The output layer is given by the second linear constructor.
#         H is also the number inputs to the second linear layer.
#         D under score out is the size of the output layer.
        self.linear2 = nn.Linear(H, D_out)
        # Define the first linear layer as an attribute, this is not good practice
        self.a1 = None
        self.l1 = None
        self.l2=None
    
    # Prediction
    def forward(self, x):
        self.l1 = self.linear1(x)
        self.a1 = sigmoid(self.l1)
        self.l2=self.linear2(self.a1)
        yhat = sigmoid(self.linear2(self.a1))
        return yhat

# %% [markdown]
# Define the training function:

# %%
# Define the training function

def train(Y, X, model, optimizer, criterion, epochs=1000):
    cost = []
    total=0
    for epoch in range(epochs):
        total=0
        for y, x in zip(Y, X):
            yhat = model(x)
            loss = criterion(yhat, y)
            loss.backward()
            optimizer.step()
            optimizer.zero_grad()
            #cumulative loss 
            total+=loss.item() 
        cost.append(total)
        if epoch % 300 == 0:    
            PlotStuff(X, Y, model, epoch, leg=True)
            plt.show()
            model(X)
            try:
                plt.scatter(model.a1.detach().numpy()[:, 0], model.a1.detach().numpy()[:, 1], c=Y.numpy().reshape(-1))
            except:
                pass    
            plt.title('activations')
            plt.show()
    return cost

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# <h2 id="Makeup_Data">Make Some Data</h2>

# %%
# Make some data

X = torch.arange(-20, 20, 1).view(-1, 1).type(torch.FloatTensor)
Y = torch.zeros(X.shape[0])
Y[(X[:, 0] > -4) & (X[:, 0] < 4)] = 1.0

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# <h2 id="Train">Define the Neural Network, Criterion Function, Optimizer and Train the Model</h2>

# %% [markdown]
# Create the Cross-Entropy loss function:

# %%
# The loss function

def criterion_cross(outputs, labels):
    out = -1 * torch.mean(labels * torch.log(outputs) + (1 - labels) * torch.log(1 - outputs))
    return out

# %% [markdown]
# Define the Neural Network, Optimizer, and Train the Model:

# %%
# Train the model
# size of input 
D_in = 1
# size of hidden layer 
H = 2
# number of outputs 
D_out = 1
# learning rate 
learning_rate = 0.1
# create the model 
model = Net(D_in, H, D_out)
#optimizer 
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)
#train the model usein
cost_cross = train(Y, X, model, optimizer, criterion_cross, epochs=1000)
#plot the loss
plt.plot(cost_cross)
plt.xlabel('epoch')
plt.title('cross entropy loss')
# Out:
# Text(0.5, 1.0, 'cross entropy loss')

# %%
model.state_dict()
# Out:
# OrderedDict([('linear1.weight', tensor([[-2.6789],
#                       [ 2.6938]])),
#              ('linear1.bias', tensor([-9.5856, -9.5552])),
#              ('linear2.weight', tensor([[-12.8212, -12.7732]])),
#              ('linear2.bias', tensor([5.7889]))])

# %% [markdown]
# By examining the output of the  activation, you see by the 600th epoch that the data has been mapped to a linearly separable space.

# %% [markdown]
# we can make a prediction for a arbitrary one tensors

# %%
# After we create a neural network object, we can apply it to a tensor as follows. 
x=torch.tensor([0.0])
yhat=model(x)
yhat
# Out:
# tensor([0.9969], grad_fn=<SigmoidBackward>)

# %% [markdown]
# we can make a prediction for some arbitrary one tensors

# %%
X_=torch.tensor([[0.0],[2.0],[3.0]])
Yhat=model(X_)
Yhat
# Out:
# tensor([[0.9969],
#         [0.9963],
#         [0.9680]], grad_fn=<SigmoidBackward>)

# %% [markdown]
# we  can threshold the predication

# %%
Yhat=Yhat>0.5
Yhat
# Out:
# tensor([[True],
#         [True],
#         [True]])

# %% [markdown]
# <h3>Practice</h3>

# %% [markdown]
# Repeat the previous steps above by using the MSE cost or total loss:

# %%
# Practice: Train the model with MSE Loss Function

# Type your code here
# Train the model
# size of input 
D_in = 1
# size of hidden layer 
H = 2
# number of outputs 
D_out = 1
# learning rate 
learning_rate = 0.1
# create the model 
model = Net(D_in, H, D_out)
model1 = torch.nn.Sequential(
    torch.nn.Linear(in_features=1,out_features=2), 
    torch.nn.Sigmoid(),
    torch.nn.Linear(in_features=2, out_features=1),
    torch.nn.Sigmoid())
                            
#optimizer 
optimizer = torch.optim.SGD(model1.parameters(), lr=learning_rate)
#train the model usein
cost_mse = train(Y, X, model1, optimizer, criterion_cross, epochs=1000)
# cost_mse = train(data_set,model1,criterion, train_loader, optimizer, epochs=600,plot_number=200)
#plot the loss
plt.plot(cost_mse)
plt.xlabel('epoch')
plt.title('cross entropy loss')
# Out:
# Text(0.5, 1.0, 'cross entropy loss')

# %% [markdown]
# Double-click <b>here</b> for the solution.
#
# <!--
# learning_rate = 0.1
# criterion_mse=nn.MSELoss()
# model=Net(D_in,H,D_out)
# optimizer=torch.optim.SGD(model.parameters(), lr=learning_rate)
# cost_mse=train(Y,X,model,optimizer,criterion_mse,epochs=1000)
# plt.plot(cost_mse)
# plt.xlabel('epoch')
# plt.title('MSE loss ')
# -->

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# <a href="http://cocl.us/pytorch_link_bottom">
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0110EN/notebook_images%20/notebook_bottom%20.png" width="750" alt="PyTorch Bottom" />
# </a>

# %% [markdown]
# <h2>About the Authors:</h2>
#
# <a href="https://www.linkedin.com/in/joseph-s-50398b136/">Joseph Santarcangelo</a> has a PhD in Electrical Engineering, his research focused on using machine learning, signal processing, and computer vision to determine how videos impact human cognition. Joseph has been working for IBM since he completed his PhD.

# %% [markdown]
# Other contributors: <a href="https://www.linkedin.com/in/michelleccarey/">Michelle Carey</a>, <a href="www.linkedin.com/in/jiahui-mavis-zhou-a4537814a">Mavis Zhou</a>

# %% [markdown]
# <hr>

# %% [markdown]
# Copyright &copy; 2018 <a href="cognitiveclass.ai?utm_source=bducopyrightlink&utm_medium=dswb&utm_campaign=bdu">cognitiveclass.ai</a>. This notebook and its source code are released under the terms of the <a href="https://bigdatauniversity.com/mit-license/">MIT License</a>.
